# %%
from fasttext import FastVector

import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import NullFormatter
from sklearn import manifold, datasets

# %matplotlib inline
# Out:
# reading word vectors from bornholmsk.300d.cc-da-aligned.all

# %%
b_vecs = FastVector(vector_file='bornholmsk.300d.cc-da-aligned.all')
#b_vecs = FastVector(vector_file='experiment/bo.300d.vec')
# Out:
# reading word vectors from bornholmsk.300d.cc-da-aligned.all

# %%
tsne = manifold.TSNE(n_components=2, init='random',
                         random_state=0, perplexity=10)
Y = tsne.fit_transform(b_vecs.embed)

# %%
plt.scatter(Y[:, 0], Y[:, 1])
